# %%
import pandas as pd
import zipfile
import os

# %%
# Define path for Landing (where the ZIP is) and Raw (where the CSV will go)
landing_zone = "/Volumes/workspace/default/landing_tickets/"
raw_zone = "/Volumes/workspace/default/landing_tickets/extracted_raw/"

# %%
# STEP 1: Update path to the EXTRACTED folder
input_path = "/Volumes/workspace/default/landing_tickets/extracted_raw/"
checkpoint_path = "/Volumes/workspace/default/landing_tickets/_checkpoints/ingestion_v3"

# %%
# STEP 2: Auto Loader
df_tickets = (spark.readStream
  .format("cloudFiles")
  .option("cloudFiles.format", "csv")
  .option("cloudFiles.schemaLocation", checkpoint_path)
  .option("cloudFiles.inferColumnTypes", "true")
  .option("header", "true")
  .load(input_path))

# %%
# STEP 3: Write to Bronze
(df_tickets.writeStream
  .option("checkpointLocation", checkpoint_path)
  .option("mergeSchema", "true")
  .trigger(availableNow=True)
  .toTable("workspace.default.bronze_tickets"))
